# %%
import os
import pandas as pd

# %%
df = pd.DataFrame(columns=['rawpath', 'icapath'])

for r in range(4, 11):
    name = 'S01_R{:02d}'.format(r)
    ds = 'S01_lixiangTHU_20190326_{:02d}.ds'.format(r)
    df = df.append(pd.Series(dict(
        rawpath=os.path.join('rawdata', ds),
        icapath=os.path.join('rawdata', '{}-clean-raw.fif'.format(name)),
    ), name=name))
    
for r in range(4, 12):
    name = 'S02_R{:02d}'.format(r)
    ds = 'S02_lixiangTHU_20190326_{:02d}.ds'.format(r)
    df = df.append(pd.Series(dict(
        rawpath=os.path.join('rawdata', ds),
        icapath=os.path.join('rawdata', '{}-clean-raw.fif'.format(name)),
    ), name=name))

df
# Out:
#                                        rawpath                        icapath
# S01_R04  rawdata/S01_lixiangTHU_20190326_04.ds  rawdata/S01_R04-clean-raw.fif
# S01_R05  rawdata/S01_lixiangTHU_20190326_05.ds  rawdata/S01_R05-clean-raw.fif
# S01_R06  rawdata/S01_lixiangTHU_20190326_06.ds  rawdata/S01_R06-clean-raw.fif
# S01_R07  rawdata/S01_lixiangTHU_20190326_07.ds  rawdata/S01_R07-clean-raw.fif
# S01_R08  rawdata/S01_lixiangTHU_20190326_08.ds  rawdata/S01_R08-clean-raw.fif
# S01_R09  rawdata/S01_lixiangTHU_20190326_09.ds  rawdata/S01_R09-clean-raw.fif
# S01_R10  rawdata/S01_lixiangTHU_20190326_10.ds  rawdata/S01_R10-clean-raw.fif
# S02_R04  rawdata/S02_lixiangTHU_20190326_04.ds  rawdata/S02_R04-clean-raw.fif
# S02_R05  rawdata/S02_lixiangTHU_20190326_05.ds  rawdata/S02_R05-clean-raw.fif
# S02_R06  rawdata/S02_lixiangTHU_20190326_06.ds  rawdata/S02_R06-clean-raw.fif
# S02_R07  rawdata/S02_lixiangTHU_20190326_07.ds  rawdata/S02_R07-clean-raw.fif
# S02_R08  rawdata/S02_lixiangTHU_20190326_08.ds  rawdata/S02_R08-clean-raw.fif
# S02_R09  rawdata/S02_lixiangTHU_20190326_09.ds  rawdata/S02_R09-clean-raw.fif
# S02_R10  rawdata/S02_lixiangTHU_20190326_10.ds  rawdata/S02_R10-clean-raw.fif
# S02_R11  rawdata/S02_lixiangTHU_20190326_11.ds  rawdata/S02_R11-clean-raw.fif

# %%
df.to_json('fifs.json')
